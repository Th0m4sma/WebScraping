# %%
import requests

response = requests.get('https://www.walissonsilva.com/')
print(response.status_code) #Retornado 200 concluimos que o acesso foi possivel...
# Out:
# 200

# %%
print(response.headers) #Imprimi o Header da página
# Out:
# {'Age': '0', 'Cache-Control': 'private, no-cache, no-store, max-age=0, must-revalidate', 'Content-Encoding': 'gzip', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Fri, 08 Nov 2024 17:21:48 GMT', 'Etag': 'W/"12032-2jzTV+XshMzPwftYn1WheHIU2bM"', 'Server': 'Vercel', 'Strict-Transport-Security': 'max-age=63072000', 'X-Matched-Path': '/', 'X-Powered-By': 'Next.js', 'X-Vercel-Cache': 'MISS', 'X-Vercel-Id': 'gru1::iad1::czvgs-1731086508639-9a7dc2e1d40d', 'Transfer-Encoding': 'chunked'}

# %%
print(response.content) #Imprimi o body do seu site
# Out:
# b'<!DOCTYPE html><html lang="pt-br"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><meta name="description" content="Site pessoal com informa\xc3\xa7\xc3\xb5es profissionais, projetos de portf\xc3\xb3lio, e blog sobre Desenvolvimento Web, Python e Ci\xc3\xaancia de Dados."/><meta property="og:title" content="Home | Walisson Silva"/><meta property="og:description" content="Site pessoal com informa\xc3\xa7\xc3\xb5es profissionais, projetos de portf\xc3\xb3lio, e blog sobre Desenvolvimento Web, Python e Ci\xc3\xaancia de Dados."/><meta property="og:image" content="/images/me-avatar.png"/><meta property="og:url" content="https://www.walissonsilva.com/"/><meta property="og:site_name" content="Walisson Silva"/><meta property="og:type" content="website"/><title>Home | Walisson Silva</title><meta name="next-head-count" content="10"/><link rel="icon" href="/favicon.svg"/><link rel="preconnect" href="https://fonts.gstatic.com"/><script async="" src="https://ww
# ...
